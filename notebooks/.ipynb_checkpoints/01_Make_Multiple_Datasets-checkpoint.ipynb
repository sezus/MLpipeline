# %%
import os
import sys
sys.path.append('..') 
import yaml
import pandas as pd
import numpy as np
import pickle
from src.data.Collect_Data_From_CSV import upload_multiple_sheets,upload_single_sheet
from src.intermediate.Clean_Normalize import clean_normalize
from src.intermediate.Create_Labels import create_labels
from src.utils.utils_p import YamlParser,save_dataset_pickle,download_pickle,Config_Paths

# %%
par
# Out:
# 'D:/Users/sezgis/Documents/Git/Diagnostic_Pitch_System'

# %%
#####LOAD CONFIG PARSE PATHS#####
#yaml file Load path:
import pathlib
p=pathlib.Path().absolute()
par=p.parent / 'src' 
CONFIG_PATH =str(par)

#Load project config from yaml file:
yaml_parser = YamlParser(CONFIG_PATH,'importcsv.yaml')
config = yaml_parser.get_yaml_file()

#Dataset Tags:
Upload_tag=config["Upload_list_all"]["Upload_Tags"]

#Select Tag to Upload
TagName=Upload_tag[0]

#Dataset Information:
tag=config["Upload_list_all"][TagName]

#Raw Data Path
raw_path=config["Upload_list_all"]['Parent_path']+"data/01_raw/" 

#Intermediate Path
intermediate_path=config["Upload_list_all"]['Parent_path']+"/data/02_intermediate/" 

#Parent Project Path
parent_path=config["Upload_list_all"]['Parent_path']
# Out:
# D:\Users\sezgis\Documents\Git\Diagnostic_Pitch_System\src
# D:\Users\sezgis\Documents\Git\Diagnostic_Pitch_System\src

# %% [markdown]
# # LOAD CSV Files

# %%
#####01_Load CSV#####
for TagName in config["Upload_list_all"]["Upload_Tags"]:
    
    #Dataset Information:
    tag=config["Upload_list_all"][TagName]
    component=config["Upload_list_all"]['External_Datasets']['Component']
    
    #01_1.Load Logs:
    Logs=upload_multiple_sheets(parent_path,tag['Path_list'],tag['File_list'],tag['Sheet_list'],tag['Range_list'],tag['refcolumn'])
    #01_2.load faults:
    Faults=upload_single_sheet(parent_path,tag['Fault_path'],tag['Fault_file'],tag['Fault_sheet'],skiprows=tag['Fault_range'])  
    #01_3.Load Category:
    FaultComponent=upload_single_sheet(parent_path,component['Path'],component['File'],component['Sheet'],skiprows=component['Range'])  
    FaultComponent=FaultComponent.drop('Unnamed: 0',axis='columns')
    
    #Save Uploaded Dataframes as Logs and Faults from Raw data:
    save_dataset_pickle(raw_path,'Logs'+TagName,Logs)
    save_dataset_pickle(raw_path,'Faults'+TagName,Faults)
    
    #External Category/Component Dataset
    save_dataset_pickle(raw_path,'FaultComponent',FaultComponent)
# Out:
# ['log', 'log', 'log', 'log']
# ['T02.xls', 'T02.xls', 'T02.xls', 'T02.xls']
# ['Gen.Operation Data', 'Gearbox Data', 'Main Bearing Data', 'Pitch System Data']
# [[0, 11], [0, 11], [0, 11], [0, 11]]
# ['log', 'log', 'log', 'log']
# ['T03.xls', 'T03.xls', 'T03.xls', 'T03.xls']
# ['Gen.Operation Data', 'Gearbox Data', 'Main Bearing Data', 'Pitch System Data']
# [[0, 11], [0, 11], [0, 11], [0, 11]]
# WARNING *** file size (64758) not 512 + multiple of sector size (512)
# ['log', 'log', 'log', 'log']
# ['T22.xls', 'T22.xls', 'T22.xls', 'T22.xls']
# ['Gen.Operation Data', 'Gearbox Data', 'Main Bearing Data', 'Pitch System Data']
# [[0, 11], [0, 11], [0, 11], [0, 11]]
# WARNING *** file size (72935) not 512 + multiple of sector size (512)
# ['log', 'log', 'log', 'log']
# ['T23.xls', 'T23.xls', 'T23.xls', 'T23.xls']
# ['Gen.Operation Data', 'Gearbox Data', 'Main Bearing Data', 'Pitch System Data']
# [[0, 11], [0, 11], [0, 11], [0, 11]]
# WARNING *** file size (81997) not 512 + multiple of sector size (512)
# ['log', 'log', 'log', 'log']
# ['T27.xls', 'T27.xls', 'T27.xls', 'T27.xls']
# ['Gen.Operation Data', 'Gearbox Data', 'Main Bearing Data', 'Pitch System Data']
# [[0, 11], [0, 11], [0, 11], [0, 11]]
# WARNING *** file size (109239) not 512 + multiple of sector size (512)

# %% [markdown]
# # Clean & Normalize Datasets

# %%
#####02_Clean & Normalize Logs(Features) data#####
for TagName in config["Upload_list_all"]["Upload_Tags"]:

    #Dataset Information:
    tag=config["Upload_list_all"][TagName]

    #Download Pickle Files
    Logs=download_pickle(raw_path,'Logs'+TagName)
    Faults=download_pickle(raw_path,'Faults'+TagName)

    #####02_Clean & Normalize Logs(Features) data#####
    #Clean and Normalize 
    Logs,Logs_not_normal,Logs_Faults=clean_normalize(config,TagName,Logs,Faults)
    
    #Save Normalize Logs & Not Normalize Logs & Combined Dataset Logs+Faults:
    save_dataset_pickle(intermediate_path,'Logs_normal_fill' + TagName,Logs)
    save_dataset_pickle(intermediate_path,'Logs_not_normal_fill'+ TagName,Logs_not_normal)
    save_dataset_pickle(intermediate_path,'Logs_Faults' + TagName,Logs_Faults)
# Out:
# Tagname are : T02
# renamecolumns are : {'Unnamed: 0': 'Period', 'Bahce 02 Power (kW)': 'Power_kW', 'Bahce 02 Rotor speed (PLC) (rpm)': 'Rotor_rpm', 'Bahce 02 Nacelle position (°)': 'Nacelle_Position', 'Bahce 02 Generator speed (PLC) (rpm)': 'Generator_rpm', 'Bahce 02 Torque, actual value (%)': 'Torque_act_Percent', 'Bahce 02 Torque, set value (%)': 'Torque_set_Percent', 'Bahce 02 Tower acceleration  normal (mm/s²)': 'Tower_acc_normal', 'Bahce 02 Tower acceleration lateral (mm/s²)': 'Tower_acc_lateral', 'Bahce 02 Temp. tower base (°C)': 'Tower_base_temp_C', 'Bahce 02 Temp. Ambient (°C)': 'Ambient_temp_C', 'Bahce 02 Windspeed a. 1 (m/s)': 'Windspeed_m_s', 'Bahce 02 Temp. gear box bearing (°C)': 'gearboxbearing_temp_C', 'Bahce 02 Temp. GBX bearing hollow shaft (°C)': 'GBX_bearing_hollow_shaft_temp_C', 'Bahce 02 T_GBX_OIL_1 (°C)': 'GBX_OIL1_temp_C', 'Bahce 02 T_GBX_OIL_2 (°C)': 'GBX_OIL2_temp_C', 'Bahce 02 T_GBX_T1-HSS (°C)': 'GBX_T1_HSS_temp_C', 'Bahce 02 T_GBX_T3-HSS (°C)': 'GBX_T3_HSS_temp_C', 'Bahce 02 T_GBX_T1-IMS (°C)': 'GBX_T1_IMS_temp_C', 'Bahce 02 T_GBX_T3-IMS (°C)': 'GBX_T3_IMS_temp_C', 'Bahce 02 T_GBX_Distr (°C)': 'GBX_Distr_temp_C', 'Bahce 02 T_GBX_OIL (°C)': 'GBX_OIL_temp_C', 'Bahce 02 Temp. shaft bearing 1 (°C)': 'Shaft_bearing1_temp_C', 'Bahce 02 Temp. shaft bearing 2 (°C)': 'Shaft_bearing2_temp_C', 'Bahce 02 Prox. sensor 45° (mm)': 'Prox_sensor45_mm', 'Bahce 02 Prox. sensor 135° (mm)': 'Prox_sensor135_mm', 'Bahce 02 Prox. sensor 225° (mm)': 'Prox_sensor225_mm', 'Bahce 02 Prox. sensor 315° (mm)': 'Prox_sensor315_mm', 'Bahce 02 Blade 2, actual value A (°)': 'Blade2_act_val_A_degree', 'Bahce 02 Blade 3, actual value A (°)': 'Blade3_act_val_A_degree', 'Bahce 02 Blade 1, set value (°)': 'Blade1_set_val_degree', 'Bahce 02 Blade 1, actual value A (°)': 'Blade1_act_val_degree'}
# Before columns Index(['Unnamed: 0', 'Bahce 02 Power (kW)', 'Bahce 02 Rotor speed (PLC) (rpm)',
#        'Bahce 02 Nacelle position (°)', 'Bahce 02 Generator speed (PLC) (rpm)',
#        'Bahce 02 Torque, actual value (%)', 'Bahce 02 Torque, set value (%)',
#        'Bahce 02 Tower acceleration  normal (mm/s²)',
#        'Bahce 02 Tower acceleration lateral (mm/s²)',
#        'Bahce 02 Temp. tower base (°C)', 'Bahce 02 Temp. Ambient (°C)',
#        'Bahce 02 Windspeed a. 1 (m/s)', 'Bahce 02 Temp. gear box bearing (°C)',
#        'Bahce 02 Temp. GBX bearing hollow shaft (°C)',
#        'Bahce 02 T_GBX_OIL_1 (°C)', 'Bahce 02 T_GBX_OIL_2 (°C)',
#        'Bahce 02 T_GBX_T1-HSS (°C)', 'Bahce 02 T_GBX_T3-HSS (°C)',
#        'Bahce 02 T_GBX_T1-IMS (°C)', 'Bahce 02 T_GBX_T3-IMS (°C)',
#        'Bahce 02 T_GBX_Distr (°C)', 'Bahce 02 T_GBX_OIL (°C)',
#        'Bahce 02 Temp. shaft bearing 1 (°C)',
#        'Bahce 02 Temp. shaft bearing 2 (°C)', 'Bahce 02 Prox. sensor 45° (mm)',
#        'Bahce 02 Prox. sensor 135° (mm)', 'Bahce 02 Prox. sensor 225° (mm)',
#        'Bahce 02 Prox. sensor 315° (mm)',
#        'Bahce 02 Blade 2, actual value A (°)',
#        'Bahce 02 Blade 3, actual value A (°)',
#        'Bahce 02 Blade 1, set value (°)',
#        'Bahce 02 Blade 1, actual value A (°)'],
#       dtype='object')
# After columns Index(['Period', 'Power_kW', 'Rotor_rpm', 'Nacelle_Position', 'Generator_rpm',
#        'Torque_act_Percent', 'Torque_set_Percent', 'Tower_acc_normal',
#        'Tower_acc_lateral', 'Tower_base_temp_C', 'Ambient_temp_C',
#        'Windspeed_m_s', 'gearboxbearing_temp_C',
#        'GBX_bearing_hollow_shaft_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C',
#        'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C',
#        'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C',
#        'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C', 'Prox_sensor45_mm',
#        'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm',
#        'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree',
#        'Blade1_set_val_degree', 'Blade1_act_val_degree'],
#       dtype='object')
# i list1
# feature_fill {'feature_fill_list': ['Ambient_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C', 'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C', 'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C', 'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C'], 'limit_conditions': [100, -5]}
# feature_fill_list ['Ambient_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C', 'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C', 'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C', 'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C']
# [100, -5]
# upperlimit 100
# lowerlimit -5
# uplimit 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
#            ...
# 45018    9.498328
# 45019    9.222036
# 45020    9.083472
# 45021    9.026711
# 45022    9.000000
# Name: Ambient_temp_C, Length: 45023, dtype: float64
# uplimit 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
#            ...
# 45018    9.498328
# 45019    9.222036
# 45020    9.083472
# 45021    9.026711
# 45022    9.000000
# Name: Ambient_temp_C, Length: 45023, dtype: float64
# uplimit 0        31.283806
# 1        32.000000
# 2        32.000000
# 3        32.000000
# 4        32.000000
#            ...
# 45018    41.000000
# 45019    41.000000
# 45020    41.000000
# 45021    41.000000
# 45022    41.073578
# Name: GBX_OIL1_temp_C, Length: 45023, dtype: float64
# uplimit 0        31.283806
# 1        32.000000
# 2        32.000000
# 3        32.000000
# 4        32.000000
#            ...
# 45018    41.000000
# 45019    41.000000
# 45020    41.000000
# 45021    41.000000
# 45022    41.073578
# Name: GBX_OIL1_temp_C, Length: 45023, dtype: float64
# uplimit 0        32.263771
# 1        33.000000
# 2        33.000000
# 3        33.000000
# 4        33.000000
#            ...
# 45018    41.000000
# 45019    41.933224
# 45020    42.125210
# 45021    42.000000
# 45022    42.107025
# Name: GBX_OIL2_temp_C, Length: 45023, dtype: float64
# uplimit 0        32.263771
# 1        33.000000
# 2        33.000000
# 3        33.000000
# 4        33.000000
#            ...
# 45018    41.000000
# 45019    41.933224
# 45020    42.125210
# 45021    42.000000
# 45022    42.107025
# Name: GBX_OIL2_temp_C, Length: 45023, dtype: float64
# uplimit 0        31.000000
# 1        31.365610
# 2        32.000000
# 3        32.000000
# 4        32.000000
#            ...
# 45018    39.000000
# 45019    39.779633
# 45020    40.198666
# 45021    40.252087
# 45022    40.816055
# Name: GBX_T1_HSS_temp_C, Length: 45023, dtype: float64
# uplimit 0        31.000000
# 1        31.365610
# 2        32.000000
# 3        32.000000
# 4        32.000000
#            ...
# 45018    39.000000
# 45019    39.779633
# 45020    40.198666
# 45021    40.252087
# 45022    40.816055
# Name: GBX_T1_HSS_temp_C, Length: 45023, dtype: float64
# uplimit 0        34.000000
# 1        34.056763
# 2        34.993332
# 3        35.000000
# 4        35.000000
#            ...
# 45018    42.821072
# 45019    43.310516
# 45020    44.579300
# 45021    44.000000
# 45022    44.152172
# Name: GBX_T3_HSS_temp_C, Length: 45023, dtype: float64
# uplimit 0        34.000000
# 1        34.056763
# 2        34.993332
# 3        35.000000
# 4        35.000000
#            ...
# 45018    42.821072
# 45019    43.310516
# 45020    44.579300
# 45021    44.000000
# 45022    44.152172
# Name: GBX_T3_HSS_temp_C, Length: 45023, dtype: float64
# uplimit 0        28.706177
# 1        29.000000
# 2        29.000000
# 3        29.444073
# 4        29.000000
#            ...
# 45018    37.964882
# 45019    38.000000
# 45020    38.707848
# 45021    38.642738
# 45022    39.000000
# Name: GBX_T1_IMS_temp_C, Length: 45023, dtype: float64
# uplimit 0        28.706177
# 1        29.000000
# 2        29.000000
# 3        29.444073
# 4        29.000000
#            ...
# 45018    37.964882
# 45019    38.000000
# 45020    38.707848
# 45021    38.642738
# 45022    39.000000
# Name: GBX_T1_IMS_temp_C, Length: 45023, dtype: float64
# uplimit 0        33.000000
# 1        33.000000
# 2        33.243332
# 3        34.000000
# 4        34.000000
#            ...
# 45018    42.000000
# 45019    42.000000
# 45020    42.853088
# 45021    43.000000
# 45022    43.000000
# Name: GBX_T3_IMS_temp_C, Length: 45023, dtype: float64
# uplimit 0        33.000000
# 1        33.000000
# 2        33.243332
# 3        34.000000
# 4        34.000000
#            ...
# 45018    42.000000
# 45019    42.000000
# 45020    42.853088
# 45021    43.000000
# 45022    43.000000
# Name: GBX_T3_IMS_temp_C, Length: 45023, dtype: float64
# uplimit 0        32.000000
# 1        32.000000
# 2        32.000000
# 3        32.402336
# 4        33.000000
#            ...
# 45018    41.000000
# 45019    41.000000
# 45020    41.878132
# 45021    41.818031
# 45022    42.000000
# Name: GBX_Distr_temp_C, Length: 45023, dtype: float64
# uplimit 0        32.000000
# 1        32.000000
# 2        32.000000
# 3        32.402336
# 4        33.000000
#            ...
# 45018    41.000000
# 45019    41.000000
# 45020    41.878132
# 45021    41.818031
# 45022    42.000000
# Name: GBX_Distr_temp_C, Length: 45023, dtype: float64
# uplimit 0        31.282137
# 1        32.000000
# 2        32.000000
# 3        32.000000
# 4        32.000000
#            ...
# 45018    41.000000
# 45019    41.000000
# 45020    41.000000
# 45021    41.000000
# 45022    41.073578
# Name: GBX_OIL_temp_C, Length: 45023, dtype: float64
# uplimit 0        31.282137
# 1        32.000000
# 2        32.000000
# 3        32.000000
# 4        32.000000
#            ...
# 45018    41.000000
# 45019    41.000000
# 45020    41.000000
# 45021    41.000000
# 45022    41.073578
# Name: GBX_OIL_temp_C, Length: 45023, dtype: float64
# uplimit 0        17.0
# 1        17.0
# 2        17.0
# 3        17.0
# 4        17.0
#          ...
# 45018    22.0
# 45019    22.0
# 45020    22.0
# 45021    22.0
# 45022    22.0
# Name: Shaft_bearing1_temp_C, Length: 45023, dtype: float64
# uplimit 0        17.0
# 1        17.0
# 2        17.0
# 3        17.0
# 4        17.0
#          ...
# 45018    22.0
# 45019    22.0
# 45020    22.0
# 45021    22.0
# 45022    22.0
# Name: Shaft_bearing1_temp_C, Length: 45023, dtype: float64
# uplimit 0        20.0
# 1        20.0
# 2        20.0
# 3        20.0
# 4        20.0
#          ...
# 45018    24.0
# 45019    24.0
# 45020    24.0
# 45021    24.0
# 45022    24.0
# Name: Shaft_bearing2_temp_C, Length: 45023, dtype: float64
# uplimit 0        20.0
# 1        20.0
# 2        20.0
# 3        20.0
# 4        20.0
#          ...
# 45018    24.0
# 45019    24.0
# 45020    24.0
# 45021    24.0
# 45022    24.0
# Name: Shaft_bearing2_temp_C, Length: 45023, dtype: float64
# i list2
# feature_fill {'feature_fill_list': ['Prox_sensor45_mm', 'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm', 'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree', 'Blade1_set_val_degree', 'Blade1_act_val_degree'], 'limit_conditions': ['None', -5]}
# feature_fill_list ['Prox_sensor45_mm', 'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm', 'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree', 'Blade1_set_val_degree', 'Blade1_act_val_degree']
# ['None', -5]
# upperlimit None
# lowerlimit -5
# uplimit 0        6.009527
# 1        6.006971
# 2        6.011072
# 3        6.005978
# 4        6.000357
#            ...
# 45018    5.988037
# 45019    5.963698
# 45020    5.963820
# 45021    5.983697
# 45022    5.964719
# Name: Prox_sensor45_mm, Length: 45023, dtype: float64
# uplimit 0        5.463154
# 1        5.473601
# 2        5.474553
# 3        5.471948
# 4        5.453260
#            ...
# 45018    5.446492
# 45019    5.448990
# 45020    5.439395
# 45021    5.446817
# 45022    5.445885
# Name: Prox_sensor135_mm, Length: 45023, dtype: float64
# uplimit 0        5.438436
# 1        5.441710
# 2        5.439465
# 3        5.438116
# 4        5.433664
#            ...
# 45018    5.421829
# 45019    5.434472
# 45020    5.426498
# 45021    5.416158
# 45022    5.423631
# Name: Prox_sensor225_mm, Length: 45023, dtype: float64
# uplimit 0        5.505246
# 1        5.498145
# 2        5.499893
# 3        5.495971
# 4        5.499868
#            ...
# 45018    5.501645
# 45019    5.485137
# 45020    5.486994
# 45021    5.490831
# 45022    5.478634
# Name: Prox_sensor315_mm, Length: 45023, dtype: float64
# uplimit 0       -0.122276
# 1       -0.125395
# 2       -0.124275
# 3        1.279380
# 4       -0.121703
#            ...
# 45018   -0.252259
# 45019   -0.279533
# 45020   -0.279724
# 45021   -0.280010
# 45022   -0.280276
# Name: Blade2_act_val_A_degree, Length: 45023, dtype: float64
# uplimit 0        0.597070
# 1        0.593381
# 2        0.597591
# 3        1.899949
# 4        0.598895
#            ...
# 45018    0.503182
# 45019    0.475684
# 45020    0.475665
# 45021    0.475614
# 45022    0.475562
# Name: Blade3_act_val_A_degree, Length: 45023, dtype: float64
# uplimit 0       -0.461130
# 1       -0.462910
# 2       -0.462151
# 3        0.990224
# 4       -0.462844
#            ...
# 45018   -0.164022
# 45019   -0.191199
# 45020   -0.191199
# 45021   -0.191199
# 45022   -0.191199
# Name: Blade1_set_val_degree, Length: 45023, dtype: float64
# uplimit 0       -0.459319
# 1       -0.460452
# 2       -0.464767
# 3        0.988417
# 4       -0.462974
#            ...
# 45018   -0.155654
# 45019   -0.179197
# 45020   -0.179216
# 45021   -0.179215
# 45022   -0.179208
# Name: Blade1_act_val_degree, Length: 45023, dtype: float64
# Tagname are : T03
# renamecolumns are : {'Unnamed: 0': 'Period', 'Bahce 03 Power (kW)': 'Power_kW', 'Bahce 03 Rotor speed (PLC) (rpm)': 'Rotor_rpm', 'Bahce 03 Nacelle position (°)': 'Nacelle_Position', 'Bahce 03 Generator speed (PLC) (rpm)': 'Generator_rpm', 'Bahce 03 Torque, actual value (%)': 'Torque_act_Percent', 'Bahce 03 Torque, set value (%)': 'Torque_set_Percent', 'Bahce 03 Tower acceleration  normal (mm/s²)': 'Tower_acc_normal', 'Bahce 03 Tower acceleration lateral (mm/s²)': 'Tower_acc_lateral', 'Bahce 03 Temp. tower base (°C)': 'Tower_base_temp_C', 'Bahce 03 Temp. Ambient (°C)': 'Ambient_temp_C', 'Bahce 03 Windspeed a. 1 (m/s)': 'Windspeed_m_s', 'Bahce 03 Temp. gear box bearing (°C)': 'gearboxbearing_temp_C', 'Bahce 03 Temp. GBX bearing hollow shaft (°C)': 'GBX_bearing_hollow_shaft_temp_C', 'Bahce 03 T_GBX_OIL_1 (°C)': 'GBX_OIL1_temp_C', 'Bahce 03 T_GBX_OIL_2 (°C)': 'GBX_OIL2_temp_C', 'Bahce 03 T_GBX_T1-HSS (°C)': 'GBX_T1_HSS_temp_C', 'Bahce 03 T_GBX_T3-HSS (°C)': 'GBX_T3_HSS_temp_C', 'Bahce 03 T_GBX_T1-IMS (°C)': 'GBX_T1_IMS_temp_C', 'Bahce 03 T_GBX_T3-IMS (°C)': 'GBX_T3_IMS_temp_C', 'Bahce 03 T_GBX_Distr (°C)': 'GBX_Distr_temp_C', 'Bahce 03 T_GBX_OIL (°C)': 'GBX_OIL_temp_C', 'Bahce 03 Temp. shaft bearing 1 (°C)': 'Shaft_bearing1_temp_C', 'Bahce 03 Temp. shaft bearing 2 (°C)': 'Shaft_bearing2_temp_C', 'Bahce 03 Prox. sensor 45° (mm)': 'Prox_sensor45_mm', 'Bahce 03 Prox. sensor 135° (mm)': 'Prox_sensor135_mm', 'Bahce 03 Prox. sensor 225° (mm)': 'Prox_sensor225_mm', 'Bahce 03 Prox. sensor 315° (mm)': 'Prox_sensor315_mm', 'Bahce 03 Blade 2, actual value A (°)': 'Blade2_act_val_A_degree', 'Bahce 03 Blade 3, actual value A (°)': 'Blade3_act_val_A_degree', 'Bahce 03 Blade 1, set value (°)': 'Blade1_set_val_degree', 'Bahce 03 Blade 1, actual value A (°)': 'Blade1_act_val_degree'}
# Before columns Index(['Unnamed: 0', 'Bahce 03 Power (kW)', 'Bahce 03 Rotor speed (PLC) (rpm)',
#        'Bahce 03 Nacelle position (°)', 'Bahce 03 Generator speed (PLC) (rpm)',
#        'Bahce 03 Torque, actual value (%)', 'Bahce 03 Torque, set value (%)',
#        'Bahce 03 Tower acceleration  normal (mm/s²)',
#        'Bahce 03 Tower acceleration lateral (mm/s²)',
#        'Bahce 03 Temp. tower base (°C)', 'Bahce 03 Temp. Ambient (°C)',
#        'Bahce 03 Windspeed a. 1 (m/s)', 'Bahce 03 Temp. gear box bearing (°C)',
#        'Bahce 03 Temp. GBX bearing hollow shaft (°C)',
#        'Bahce 03 T_GBX_OIL_1 (°C)', 'Bahce 03 T_GBX_OIL_2 (°C)',
#        'Bahce 03 T_GBX_T1-HSS (°C)', 'Bahce 03 T_GBX_T3-HSS (°C)',
#        'Bahce 03 T_GBX_T1-IMS (°C)', 'Bahce 03 T_GBX_T3-IMS (°C)',
#        'Bahce 03 T_GBX_Distr (°C)', 'Bahce 03 T_GBX_OIL (°C)',
#        'Bahce 03 Temp. shaft bearing 1 (°C)',
#        'Bahce 03 Temp. shaft bearing 2 (°C)', 'Bahce 03 Prox. sensor 45° (mm)',
#        'Bahce 03 Prox. sensor 135° (mm)', 'Bahce 03 Prox. sensor 225° (mm)',
#        'Bahce 03 Prox. sensor 315° (mm)',
#        'Bahce 03 Blade 2, actual value A (°)',
#        'Bahce 03 Blade 3, actual value A (°)',
#        'Bahce 03 Blade 1, set value (°)',
#        'Bahce 03 Blade 1, actual value A (°)'],
#       dtype='object')
# After columns Index(['Period', 'Power_kW', 'Rotor_rpm', 'Nacelle_Position', 'Generator_rpm',
#        'Torque_act_Percent', 'Torque_set_Percent', 'Tower_acc_normal',
#        'Tower_acc_lateral', 'Tower_base_temp_C', 'Ambient_temp_C',
#        'Windspeed_m_s', 'gearboxbearing_temp_C',
#        'GBX_bearing_hollow_shaft_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C',
#        'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C',
#        'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C',
#        'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C', 'Prox_sensor45_mm',
#        'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm',
#        'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree',
#        'Blade1_set_val_degree', 'Blade1_act_val_degree'],
#       dtype='object')
# i list1
# feature_fill {'feature_fill_list': ['Ambient_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C', 'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C', 'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C', 'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C'], 'limit_conditions': [100, -5]}
# feature_fill_list ['Ambient_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C', 'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C', 'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C', 'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C']
# [100, -5]
# upperlimit 100
# lowerlimit -5
# uplimit 0         1.000000
# 1         1.000000
# 2         1.000000
# 3         1.000000
# 4         1.000000
#            ...
# 48094    10.000000
# 48095    10.000000
# 48096     9.575000
# 48097     9.038333
# 48098     9.158334
# Name: Ambient_temp_C, Length: 48099, dtype: float64
# uplimit 0         1.000000
# 1         1.000000
# 2         1.000000
# 3         1.000000
# 4         1.000000
#            ...
# 48094    10.000000
# 48095    10.000000
# 48096     9.575000
# 48097     9.038333
# 48098     9.158334
# Name: Ambient_temp_C, Length: 48099, dtype: float64
# uplimit 0        35.000000
# 1        35.616665
# 2        36.000000
# 3        35.751667
# 4        36.000000
#            ...
# 48094    34.000000
# 48095    33.773335
# 48096    34.150002
# 48097    36.160000
# 48098    37.000000
# Name: GBX_OIL1_temp_C, Length: 48099, dtype: float64
# uplimit 0        35.000000
# 1        35.616665
# 2        36.000000
# 3        35.751667
# 4        36.000000
#            ...
# 48094    34.000000
# 48095    33.773335
# 48096    34.150002
# 48097    36.160000
# 48098    37.000000
# Name: GBX_OIL1_temp_C, Length: 48099, dtype: float64
# uplimit 0        39.000000
# 1        39.058334
# 2        39.146667
# 3        39.000000
# 4        39.000000
#            ...
# 48094    39.000000
# 48095    38.584999
# 48096    38.555000
# 48097    40.318333
# 48098    41.029999
# Name: GBX_OIL2_temp_C, Length: 48099, dtype: float64
# uplimit 0        39.000000
# 1        39.058334
# 2        39.146667
# 3        39.000000
# 4        39.000000
#            ...
# 48094    39.000000
# 48095    38.584999
# 48096    38.555000
# 48097    40.318333
# 48098    41.029999
# Name: GBX_OIL2_temp_C, Length: 48099, dtype: float64
# uplimit 0        38.000000
# 1        38.113335
# 2        38.908333
# 3        39.000000
# 4        39.000000
#            ...
# 48094    38.035000
# 48095    37.270000
# 48096    37.513332
# 48097    40.625000
# 48098    42.770000
# Name: GBX_T1_HSS_temp_C, Length: 48099, dtype: float64
# uplimit 0        38.000000
# 1        38.113335
# 2        38.908333
# 3        39.000000
# 4        39.000000
#            ...
# 48094    38.035000
# 48095    37.270000
# 48096    37.513332
# 48097    40.625000
# 48098    42.770000
# Name: GBX_T1_HSS_temp_C, Length: 48099, dtype: float64
# uplimit 0        39.000000
# 1        39.000000
# 2        39.000000
# 3        39.000000
# 4        39.000000
#            ...
# 48094    36.959999
# 48095    36.000000
# 48096    36.275002
# 48097    39.619999
# 48098    42.433334
# Name: GBX_T3_HSS_temp_C, Length: 48099, dtype: float64
# uplimit 0        39.000000
# 1        39.000000
# 2        39.000000
# 3        39.000000
# 4        39.000000
#            ...
# 48094    36.959999
# 48095    36.000000
# 48096    36.275002
# 48097    39.619999
# 48098    42.433334
# Name: GBX_T3_HSS_temp_C, Length: 48099, dtype: float64
# uplimit 0        38.000000
# 1        38.000000
# 2        38.000000
# 3        38.000000
# 4        38.000000
#            ...
# 48094    37.091667
# 48095    36.998333
# 48096    37.355000
# 48097    40.738335
# 48098    42.145000
# Name: GBX_T1_IMS_temp_C, Length: 48099, dtype: float64
# uplimit 0        38.000000
# 1        38.000000
# 2        38.000000
# 3        38.000000
# 4        38.000000
#            ...
# 48094    37.091667
# 48095    36.998333
# 48096    37.355000
# 48097    40.738335
# 48098    42.145000
# Name: GBX_T1_IMS_temp_C, Length: 48099, dtype: float64
# uplimit 0        39.000000
# 1        39.000000
# 2        39.000000
# 3        39.000000
# 4        39.000000
#            ...
# 48094    39.323334
# 48095    39.000000
# 48096    39.000000
# 48097    39.000000
# 48098    39.983334
# Name: GBX_T3_IMS_temp_C, Length: 48099, dtype: float64
# uplimit 0        39.000000
# 1        39.000000
# 2        39.000000
# 3        39.000000
# 4        39.000000
#            ...
# 48094    39.323334
# 48095    39.000000
# 48096    39.000000
# 48097    39.000000
# 48098    39.983334
# Name: GBX_T3_IMS_temp_C, Length: 48099, dtype: float64
# uplimit 0        36.000000
# 1        36.000000
# 2        36.490002
# 3        36.000000
# 4        36.000000
#            ...
# 48094    31.736666
# 48095    30.356667
# 48096    32.906666
# 48097    36.428333
# 48098    37.818333
# Name: GBX_Distr_temp_C, Length: 48099, dtype: float64
# uplimit 0        36.000000
# 1        36.000000
# 2        36.490002
# 3        36.000000
# 4        36.000000
#            ...
# 48094    31.736666
# 48095    30.356667
# 48096    32.906666
# 48097    36.428333
# 48098    37.818333
# Name: GBX_Distr_temp_C, Length: 48099, dtype: float64
# uplimit 0        35.000000
# 1        35.618332
# 2        36.000000
# 3        35.751667
# 4        36.000000
#            ...
# 48094    34.000000
# 48095    33.773335
# 48096    34.150002
# 48097    36.160000
# 48098    37.000000
# Name: GBX_OIL_temp_C, Length: 48099, dtype: float64
# uplimit 0        35.000000
# 1        35.618332
# 2        36.000000
# 3        35.751667
# 4        36.000000
#            ...
# 48094    34.000000
# 48095    33.773335
# 48096    34.150002
# 48097    36.160000
# 48098    37.000000
# Name: GBX_OIL_temp_C, Length: 48099, dtype: float64
# uplimit 0        22.000000
# 1        22.000000
# 2        22.000000
# 3        22.000000
# 4        22.000000
#            ...
# 48094    21.000000
# 48095    21.108334
# 48096    22.000000
# 48097    22.000000
# 48098          NaN
# Name: Shaft_bearing1_temp_C, Length: 48099, dtype: float64
# uplimit 0        22.000000
# 1        22.000000
# 2        22.000000
# 3        22.000000
# 4        22.000000
#            ...
# 48094    21.000000
# 48095    21.108334
# 48096    22.000000
# 48097    22.000000
# 48098          NaN
# Name: Shaft_bearing1_temp_C, Length: 48099, dtype: float64
# uplimit 0        18.000000
# 1        18.000000
# 2        18.000000
# 3        18.298334
# 4        19.000000
#            ...
# 48094    20.000000
# 48095    20.000000
# 48096    20.379999
# 48097    21.000000
# 48098          NaN
# Name: Shaft_bearing2_temp_C, Length: 48099, dtype: float64
# uplimit 0        18.000000
# 1        18.000000
# 2        18.000000
# 3        18.298334
# 4        19.000000
#            ...
# 48094    20.000000
# 48095    20.000000
# 48096    20.379999
# 48097    21.000000
# 48098          NaN
# Name: Shaft_bearing2_temp_C, Length: 48099, dtype: float64
# i list2
# feature_fill {'feature_fill_list': ['Prox_sensor45_mm', 'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm', 'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree', 'Blade1_set_val_degree', 'Blade1_act_val_degree'], 'limit_conditions': ['None', -5]}
# feature_fill_list ['Prox_sensor45_mm', 'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm', 'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree', 'Blade1_set_val_degree', 'Blade1_act_val_degree']
# ['None', -5]
# upperlimit None
# lowerlimit -5
# uplimit 0        5.602018
# 1        5.594197
# 2        5.602457
# 3        5.602617
# 4        5.602836
#            ...
# 48094    5.609454
# 48095    5.560900
# 48096    5.523951
# 48097    5.585426
# 48098         NaN
# Name: Prox_sensor45_mm, Length: 48099, dtype: float64
# uplimit 0        5.455513
# 1        5.457189
# 2        5.449530
# 3        5.453165
# 4        5.449776
#            ...
# 48094    5.454591
# 48095    5.412875
# 48096    5.407417
# 48097    5.432928
# 48098         NaN
# Name: Prox_sensor135_mm, Length: 48099, dtype: float64
# uplimit 0        5.486113
# 1        5.490232
# 2        5.480562
# 3        5.480217
# 4        5.484007
#            ...
# 48094    5.482707
# 48095    5.474229
# 48096    5.455573
# 48097    5.420425
# 48098         NaN
# Name: Prox_sensor225_mm, Length: 48099, dtype: float64
# uplimit 0        5.747852
# 1        5.742475
# 2        5.749503
# 3        5.746600
# 4        5.753015
#            ...
# 48094    5.755488
# 48095    5.734081
# 48096    5.686974
# 48097    5.696245
# 48098         NaN
# Name: Prox_sensor315_mm, Length: 48099, dtype: float64
# uplimit 0         0.006815
# 1         0.019747
# 2         0.104368
# 3         0.059824
# 4         0.014726
#            ...
# 48094    65.001022
# 48095    65.001022
# 48096    15.542382
# 48097     1.076368
# 48098          NaN
# Name: Blade2_act_val_A_degree, Length: 48099, dtype: float64
# uplimit 0         0.007938
# 1         0.020548
# 2         0.098894
# 3         0.062499
# 4         0.023620
#            ...
# 48094    64.998589
# 48095    64.998581
# 48096    15.360627
# 48097     0.771003
# 48098          NaN
# Name: Blade3_act_val_A_degree, Length: 48099, dtype: float64
# uplimit 0         0.001835
# 1         0.016911
# 2         0.098468
# 3         0.059035
# 4         0.016394
#            ...
# 48094    65.000000
# 48095    65.000000
# 48096    15.561797
# 48097     1.151146
# 48098          NaN
# Name: Blade1_set_val_degree, Length: 48099, dtype: float64
# uplimit 0         0.001888
# 1         0.019176
# 2         0.103877
# 3         0.063925
# 4         0.018593
#            ...
# 48094    65.002823
# 48095    65.002831
# 48096    15.589321
# 48097     1.154293
# 48098          NaN
# Name: Blade1_act_val_degree, Length: 48099, dtype: float64
# Tagname are : T22
# renamecolumns are : {'Unnamed: 0': 'Period', 'Bahce 22 Power (kW)': 'Power_kW', 'Bahce 22 Rotor speed (PLC) (rpm)': 'Rotor_rpm', 'Bahce 22 Nacelle position (°)': 'Nacelle_Position', 'Bahce 22 Generator speed (PLC) (rpm)': 'Generator_rpm', 'Bahce 22 Torque, actual value (%)': 'Torque_act_Percent', 'Bahce 22 Torque, set value (%)': 'Torque_set_Percent', 'Bahce 22 Tower acceleration  normal (mm/s²)': 'Tower_acc_normal', 'Bahce 22 Tower acceleration lateral (mm/s²)': 'Tower_acc_lateral', 'Bahce 22 Temp. tower base (°C)': 'Tower_base_temp_C', 'Bahce 22 Temp. Ambient (°C)': 'Ambient_temp_C', 'Bahce 22 Windspeed a. 1 (m/s)': 'Windspeed_m_s', 'Bahce 22 Temp. gear box bearing (°C)': 'gearboxbearing_temp_C', 'Bahce 22 Temp. GBX bearing hollow shaft (°C)': 'GBX_bearing_hollow_shaft_temp_C', 'Bahce 22 T_GBX_OIL_1 (°C)': 'GBX_OIL1_temp_C', 'Bahce 22 T_GBX_OIL_2 (°C)': 'GBX_OIL2_temp_C', 'Bahce 22 T_GBX_T1-HSS (°C)': 'GBX_T1_HSS_temp_C', 'Bahce 22 T_GBX_T3-HSS (°C)': 'GBX_T3_HSS_temp_C', 'Bahce 22 T_GBX_T1-IMS (°C)': 'GBX_T1_IMS_temp_C', 'Bahce 22 T_GBX_T3-IMS (°C)': 'GBX_T3_IMS_temp_C', 'Bahce 22 T_GBX_Distr (°C)': 'GBX_Distr_temp_C', 'Bahce 22 T_GBX_OIL (°C)': 'GBX_OIL_temp_C', 'Bahce 22 Temp. shaft bearing 1 (°C)': 'Shaft_bearing1_temp_C', 'Bahce 22 Temp. shaft bearing 2 (°C)': 'Shaft_bearing2_temp_C', 'Bahce 22 Prox. sensor 45° (mm)': 'Prox_sensor45_mm', 'Bahce 22 Prox. sensor 135° (mm)': 'Prox_sensor135_mm', 'Bahce 22 Prox. sensor 225° (mm)': 'Prox_sensor225_mm', 'Bahce 22 Prox. sensor 315° (mm)': 'Prox_sensor315_mm', 'Bahce 22 Blade 2, actual value A (°)': 'Blade2_act_val_A_degree', 'Bahce 22 Blade 3, actual value A (°)': 'Blade3_act_val_A_degree', 'Bahce 22 Blade 1, set value (°)': 'Blade1_set_val_degree', 'Bahce 22 Blade 1, actual value A (°)': 'Blade1_act_val_degree'}
# Before columns Index(['Unnamed: 0', 'Bahce 22 Power (kW)', 'Bahce 22 Rotor speed (PLC) (rpm)',
#        'Bahce 22 Nacelle position (°)', 'Bahce 22 Generator speed (PLC) (rpm)',
#        'Bahce 22 Torque, actual value (%)', 'Bahce 22 Torque, set value (%)',
#        'Bahce 22 Tower acceleration  normal (mm/s²)',
#        'Bahce 22 Tower acceleration lateral (mm/s²)',
#        'Bahce 22 Temp. tower base (°C)', 'Bahce 22 Temp. Ambient (°C)',
#        'Bahce 22 Windspeed a. 1 (m/s)', 'Bahce 22 Temp. gear box bearing (°C)',
#        'Bahce 22 Temp. GBX bearing hollow shaft (°C)',
#        'Bahce 22 T_GBX_OIL_1 (°C)', 'Bahce 22 T_GBX_OIL_2 (°C)',
#        'Bahce 22 T_GBX_T1-HSS (°C)', 'Bahce 22 T_GBX_T3-HSS (°C)',
#        'Bahce 22 T_GBX_T1-IMS (°C)', 'Bahce 22 T_GBX_T3-IMS (°C)',
#        'Bahce 22 T_GBX_Distr (°C)', 'Bahce 22 T_GBX_OIL (°C)',
#        'Bahce 22 Temp. shaft bearing 1 (°C)',
#        'Bahce 22 Temp. shaft bearing 2 (°C)', 'Bahce 22 Prox. sensor 45° (mm)',
#        'Bahce 22 Prox. sensor 135° (mm)', 'Bahce 22 Prox. sensor 225° (mm)',
#        'Bahce 22 Prox. sensor 315° (mm)',
#        'Bahce 22 Blade 2, actual value A (°)',
#        'Bahce 22 Blade 3, actual value A (°)',
#        'Bahce 22 Blade 1, set value (°)',
#        'Bahce 22 Blade 1, actual value A (°)'],
#       dtype='object')
# After columns Index(['Period', 'Power_kW', 'Rotor_rpm', 'Nacelle_Position', 'Generator_rpm',
#        'Torque_act_Percent', 'Torque_set_Percent', 'Tower_acc_normal',
#        'Tower_acc_lateral', 'Tower_base_temp_C', 'Ambient_temp_C',
#        'Windspeed_m_s', 'gearboxbearing_temp_C',
#        'GBX_bearing_hollow_shaft_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C',
#        'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C',
#        'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C',
#        'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C', 'Prox_sensor45_mm',
#        'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm',
#        'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree',
#        'Blade1_set_val_degree', 'Blade1_act_val_degree'],
#       dtype='object')
# i list1
# feature_fill {'feature_fill_list': ['Ambient_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C', 'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C', 'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C', 'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C'], 'limit_conditions': [100, -5]}
# feature_fill_list ['Ambient_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C', 'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C', 'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C', 'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C']
# [100, -5]
# upperlimit 100
# lowerlimit -5
# uplimit 0         2.000000
# 1         2.000000
# 2         1.853333
# 3         2.000000
# 4         1.946667
#            ...
# 47698    10.000000
# 47699    10.000000
# 47700     9.268333
# 47701     9.000000
# 47702     9.130000
# Name: Ambient_temp_C, Length: 47703, dtype: float64
# uplimit 0         2.000000
# 1         2.000000
# 2         1.853333
# 3         2.000000
# 4         1.946667
#            ...
# 47698    10.000000
# 47699    10.000000
# 47700     9.268333
# 47701     9.000000
# 47702     9.130000
# Name: Ambient_temp_C, Length: 47703, dtype: float64
# uplimit 0         2.000000
# 1         2.000000
# 2         2.000000
# 3         2.000000
# 4         2.000000
#            ...
# 47698    43.931667
# 47699    42.136665
# 47700    41.921665
# 47701    43.003334
# 47702    44.000000
# Name: GBX_OIL1_temp_C, Length: 47703, dtype: float64
# uplimit 0         2.000000
# 1         2.000000
# 2         2.000000
# 3         2.000000
# 4         2.000000
#            ...
# 47698    43.931667
# 47699    42.136665
# 47700    41.921665
# 47701    43.003334
# 47702    44.000000
# Name: GBX_OIL1_temp_C, Length: 47703, dtype: float64
# uplimit 0         1.631052
# 1         1.506667
# 2         1.323333
# 3         1.641667
# 4         1.698333
#            ...
# 47698    44.488335
# 47699    40.226665
# 47700    41.445000
# 47701    43.709999
# 47702    44.391666
# Name: GBX_OIL2_temp_C, Length: 47703, dtype: float64
# uplimit 0         1.631052
# 1         1.506667
# 2         1.323333
# 3         1.641667
# 4         1.698333
#            ...
# 47698    44.488335
# 47699    40.226665
# 47700    41.445000
# 47701    43.709999
# 47702    44.391666
# Name: GBX_OIL2_temp_C, Length: 47703, dtype: float64
# uplimit 0         1.000000
# 1         1.000000
# 2         1.000000
# 3         1.000000
# 4         1.000000
#            ...
# 47698    41.798332
# 47699    40.213333
# 47700    39.936668
# 47701    42.950001
# 47702    44.693333
# Name: GBX_T1_HSS_temp_C, Length: 47703, dtype: float64
# uplimit 0         1.000000
# 1         1.000000
# 2         1.000000
# 3         1.000000
# 4         1.000000
#            ...
# 47698    41.798332
# 47699    40.213333
# 47700    39.936668
# 47701    42.950001
# 47702    44.693333
# Name: GBX_T1_HSS_temp_C, Length: 47703, dtype: float64
# uplimit 0         2.000000
# 1         2.000000
# 2         2.000000
# 3         2.000000
# 4         2.000000
#            ...
# 47698    41.921665
# 47699    40.615002
# 47700    40.281666
# 47701    42.264999
# 47702    43.836666
# Name: GBX_T3_HSS_temp_C, Length: 47703, dtype: float64
# uplimit 0         2.000000
# 1         2.000000
# 2         2.000000
# 3         2.000000
# 4         2.000000
#            ...
# 47698    41.921665
# 47699    40.615002
# 47700    40.281666
# 47701    42.264999
# 47702    43.836666
# Name: GBX_T3_HSS_temp_C, Length: 47703, dtype: float64
# uplimit 0         1.000000
# 1         1.000000
# 2         1.000000
# 3         1.000000
# 4         1.000000
#            ...
# 47698    42.666668
# 47699    41.048332
# 47700    40.310001
# 47701    42.471668
# 47702    43.816666
# Name: GBX_T1_IMS_temp_C, Length: 47703, dtype: float64
# uplimit 0         1.000000
# 1         1.000000
# 2         1.000000
# 3         1.000000
# 4         1.000000
#            ...
# 47698    42.666668
# 47699    41.048332
# 47700    40.310001
# 47701    42.471668
# 47702    43.816666
# Name: GBX_T1_IMS_temp_C, Length: 47703, dtype: float64
# uplimit 0         1.577629
# 1         1.171667
# 2         1.005000
# 3         1.051667
# 4         1.050000
#            ...
# 47698    45.230000
# 47699    44.470001
# 47700    43.578335
# 47701    43.000000
# 47702    43.000000
# Name: GBX_T3_IMS_temp_C, Length: 47703, dtype: float64
# uplimit 0         1.577629
# 1         1.171667
# 2         1.005000
# 3         1.051667
# 4         1.050000
#            ...
# 47698    45.230000
# 47699    44.470001
# 47700    43.578335
# 47701    43.000000
# 47702    43.000000
# Name: GBX_T3_IMS_temp_C, Length: 47703, dtype: float64
# uplimit 0         1.000000
# 1         1.000000
# 2         1.000000
# 3         1.000000
# 4         1.048333
#            ...
# 47698    35.570000
# 47699    34.423332
# 47700    35.298332
# 47701    38.540001
# 47702    39.869999
# Name: GBX_Distr_temp_C, Length: 47703, dtype: float64
# uplimit 0         1.000000
# 1         1.000000
# 2         1.000000
# 3         1.000000
# 4         1.048333
#            ...
# 47698    35.570000
# 47699    34.423332
# 47700    35.298332
# 47701    38.540001
# 47702    39.869999
# Name: GBX_Distr_temp_C, Length: 47703, dtype: float64
# uplimit 0         2.000000
# 1         2.000000
# 2         2.000000
# 3         2.000000
# 4         2.000000
#            ...
# 47698    43.931667
# 47699    42.136665
# 47700    41.921665
# 47701    43.003334
# 47702    44.000000
# Name: GBX_OIL_temp_C, Length: 47703, dtype: float64
# uplimit 0         2.000000
# 1         2.000000
# 2         2.000000
# 3         2.000000
# 4         2.000000
#            ...
# 47698    43.931667
# 47699    42.136665
# 47700    41.921665
# 47701    43.003334
# 47702    44.000000
# Name: GBX_OIL_temp_C, Length: 47703, dtype: float64
# uplimit 0         2.000000
# 1         2.000000
# 2         2.000000
# 3         2.000000
# 4         2.000000
#            ...
# 47698    27.000000
# 47699    27.000000
# 47700    27.000000
# 47701    27.393333
# 47702    28.000000
# Name: Shaft_bearing1_temp_C, Length: 47703, dtype: float64
# uplimit 0         2.000000
# 1         2.000000
# 2         2.000000
# 3         2.000000
# 4         2.000000
#            ...
# 47698    27.000000
# 47699    27.000000
# 47700    27.000000
# 47701    27.393333
# 47702    28.000000
# Name: Shaft_bearing1_temp_C, Length: 47703, dtype: float64
# uplimit 0         3.0
# 1         3.0
# 2         3.0
# 3         3.0
# 4         3.0
#          ...
# 47698    25.0
# 47699    25.0
# 47700    25.0
# 47701    25.0
# 47702    25.0
# Name: Shaft_bearing2_temp_C, Length: 47703, dtype: float64
# uplimit 0         3.0
# 1         3.0
# 2         3.0
# 3         3.0
# 4         3.0
#          ...
# 47698    25.0
# 47699    25.0
# 47700    25.0
# 47701    25.0
# 47702    25.0
# Name: Shaft_bearing2_temp_C, Length: 47703, dtype: float64
# i list2
# feature_fill {'feature_fill_list': ['Prox_sensor45_mm', 'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm', 'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree', 'Blade1_set_val_degree', 'Blade1_act_val_degree'], 'limit_conditions': ['None', -5]}
# feature_fill_list ['Prox_sensor45_mm', 'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm', 'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree', 'Blade1_set_val_degree', 'Blade1_act_val_degree']
# ['None', -5]
# upperlimit None
# lowerlimit -5
# uplimit 0        5.510034
# 1        5.510000
# 2        5.510000
# 3        5.510033
# 4        5.510016
#            ...
# 47698    5.580966
# 47699    5.570467
# 47700    5.574833
# 47701    5.581183
# 47702    5.572650
# Name: Prox_sensor45_mm, Length: 47703, dtype: float64
# uplimit 0        5.410000
# 1        5.410000
# 2        5.410000
# 3        5.410000
# 4        5.410000
#            ...
# 47698    5.448633
# 47699    5.461667
# 47700    5.463333
# 47701    5.465200
# 47702    5.464400
# Name: Prox_sensor135_mm, Length: 47703, dtype: float64
# uplimit 0        5.469983
# 1        5.470000
# 2        5.470000
# 3        5.469934
# 4        5.469983
#            ...
# 47698    5.461633
# 47699    5.473783
# 47700    5.481167
# 47701    5.479700
# 47702    5.483833
# Name: Prox_sensor225_mm, Length: 47703, dtype: float64
# uplimit 0        5.590200
# 1        5.590000
# 2        5.590034
# 3        5.590416
# 4        5.590267
#            ...
# 47698    5.628867
# 47699    5.619067
# 47700    5.627750
# 47701    5.634217
# 47702    5.627767
# Name: Prox_sensor315_mm, Length: 47703, dtype: float64
# uplimit 0        251.300003
# 1        251.300003
# 2        251.300003
# 3        251.300003
# 4        251.300003
#             ...
# 47698      1.454233
# 47699      1.461750
# 47700      1.484533
# 47701      1.145550
# 47702      1.484533
# Name: Blade2_act_val_A_degree, Length: 47703, dtype: float64
# uplimit 0       -53.610001
# 1       -53.610001
# 2       -53.610001
# 3       -53.610001
# 4       -53.610001
#            ...
# 47698     1.344483
# 47699     1.346100
# 47700     1.364933
# 47701     1.032383
# 47702     1.364933
# Name: Blade3_act_val_A_degree, Length: 47703, dtype: float64
# uplimit 0        89.000000
# 1        89.000000
# 2        89.000000
# 3        89.000000
# 4        89.000000
#            ...
# 47698     1.614167
# 47699     1.610000
# 47700     1.625000
# 47701     1.302500
# 47702     1.625000
# Name: Blade1_set_val_degree, Length: 47703, dtype: float64
# uplimit 0        89.000000
# 1        89.000000
# 2        89.000000
# 3        89.000000
# 4        89.000000
#            ...
# 47698     1.623317
# 47699     1.607700
# 47700     1.615667
# 47701     1.309133
# 47702     1.615667
# Name: Blade1_act_val_degree, Length: 47703, dtype: float64
# Tagname are : T23
# renamecolumns are : {'Unnamed: 0': 'Period', 'Bahce 23 Power (kW)': 'Power_kW', 'Bahce 23 Rotor speed (PLC) (rpm)': 'Rotor_rpm', 'Bahce 23 Nacelle position (°)': 'Nacelle_Position', 'Bahce 23 Generator speed (PLC) (rpm)': 'Generator_rpm', 'Bahce 23 Torque, actual value (%)': 'Torque_act_Percent', 'Bahce 23 Torque, set value (%)': 'Torque_set_Percent', 'Bahce 23 Tower acceleration  normal (mm/s²)': 'Tower_acc_normal', 'Bahce 23 Tower acceleration lateral (mm/s²)': 'Tower_acc_lateral', 'Bahce 23 Temp. tower base (°C)': 'Tower_base_temp_C', 'Bahce 23 Temp. Ambient (°C)': 'Ambient_temp_C', 'Bahce 23 Windspeed a. 1 (m/s)': 'Windspeed_m_s', 'Bahce 23 Temp. gear box bearing (°C)': 'gearboxbearing_temp_C', 'Bahce 23 Temp. GBX bearing hollow shaft (°C)': 'GBX_bearing_hollow_shaft_temp_C', 'Bahce 23 T_GBX_OIL_1 (°C)': 'GBX_OIL1_temp_C', 'Bahce 23 T_GBX_OIL_2 (°C)': 'GBX_OIL2_temp_C', 'Bahce 23 T_GBX_T1-HSS (°C)': 'GBX_T1_HSS_temp_C', 'Bahce 23 T_GBX_T3-HSS (°C)': 'GBX_T3_HSS_temp_C', 'Bahce 23 T_GBX_T1-IMS (°C)': 'GBX_T1_IMS_temp_C', 'Bahce 23 T_GBX_T3-IMS (°C)': 'GBX_T3_IMS_temp_C', 'Bahce 23 T_GBX_Distr (°C)': 'GBX_Distr_temp_C', 'Bahce 23 T_GBX_OIL (°C)': 'GBX_OIL_temp_C', 'Bahce 23 Temp. shaft bearing 1 (°C)': 'Shaft_bearing1_temp_C', 'Bahce 23 Temp. shaft bearing 2 (°C)': 'Shaft_bearing2_temp_C', 'Bahce 23 Prox. sensor 45° (mm)': 'Prox_sensor45_mm', 'Bahce 23 Prox. sensor 135° (mm)': 'Prox_sensor135_mm', 'Bahce 23 Prox. sensor 225° (mm)': 'Prox_sensor225_mm', 'Bahce 23 Prox. sensor 315° (mm)': 'Prox_sensor315_mm', 'Bahce 23 Blade 2, actual value A (°)': 'Blade2_act_val_A_degree', 'Bahce 23 Blade 3, actual value A (°)': 'Blade3_act_val_A_degree', 'Bahce 23 Blade 1, set value (°)': 'Blade1_set_val_degree', 'Bahce 23 Blade 1, actual value A (°)': 'Blade1_act_val_degree'}
# Before columns Index(['Unnamed: 0', 'Bahce 23 Power (kW)', 'Bahce 23 Rotor speed (PLC) (rpm)',
#        'Bahce 23 Nacelle position (°)', 'Bahce 23 Generator speed (PLC) (rpm)',
#        'Bahce 23 Torque, actual value (%)', 'Bahce 23 Torque, set value (%)',
#        'Bahce 23 Tower acceleration  normal (mm/s²)',
#        'Bahce 23 Tower acceleration lateral (mm/s²)',
#        'Bahce 23 Temp. tower base (°C)', 'Bahce 23 Temp. Ambient (°C)',
#        'Bahce 23 Windspeed a. 1 (m/s)', 'Bahce 23 Temp. gear box bearing (°C)',
#        'Bahce 23 Temp. GBX bearing hollow shaft (°C)',
#        'Bahce 23 T_GBX_OIL_1 (°C)', 'Bahce 23 T_GBX_OIL_2 (°C)',
#        'Bahce 23 T_GBX_T1-HSS (°C)', 'Bahce 23 T_GBX_T3-HSS (°C)',
#        'Bahce 23 T_GBX_T1-IMS (°C)', 'Bahce 23 T_GBX_T3-IMS (°C)',
#        'Bahce 23 T_GBX_Distr (°C)', 'Bahce 23 T_GBX_OIL (°C)',
#        'Bahce 23 Temp. shaft bearing 1 (°C)',
#        'Bahce 23 Temp. shaft bearing 2 (°C)', 'Bahce 23 Prox. sensor 45° (mm)',
#        'Bahce 23 Prox. sensor 135° (mm)', 'Bahce 23 Prox. sensor 225° (mm)',
#        'Bahce 23 Prox. sensor 315° (mm)',
#        'Bahce 23 Blade 2, actual value A (°)',
#        'Bahce 23 Blade 3, actual value A (°)',
#        'Bahce 23 Blade 1, set value (°)',
#        'Bahce 23 Blade 1, actual value A (°)'],
#       dtype='object')
# After columns Index(['Period', 'Power_kW', 'Rotor_rpm', 'Nacelle_Position', 'Generator_rpm',
#        'Torque_act_Percent', 'Torque_set_Percent', 'Tower_acc_normal',
#        'Tower_acc_lateral', 'Tower_base_temp_C', 'Ambient_temp_C',
#        'Windspeed_m_s', 'gearboxbearing_temp_C',
#        'GBX_bearing_hollow_shaft_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C',
#        'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C',
#        'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C',
#        'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C', 'Prox_sensor45_mm',
#        'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm',
#        'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree',
#        'Blade1_set_val_degree', 'Blade1_act_val_degree'],
#       dtype='object')
# i list1
# feature_fill {'feature_fill_list': ['Ambient_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C', 'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C', 'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C', 'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C'], 'limit_conditions': [100, -5]}
# feature_fill_list ['Ambient_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C', 'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C', 'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C', 'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C']
# [100, -5]
# upperlimit 100
# lowerlimit -5
# uplimit 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 46554    9.0
# 46555    9.0
# 46556    9.0
# 46557    9.0
# 46558    9.0
# Name: Ambient_temp_C, Length: 46559, dtype: float64
# uplimit 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 46554    9.0
# 46555    9.0
# 46556    9.0
# 46557    9.0
# 46558    9.0
# Name: Ambient_temp_C, Length: 46559, dtype: float64
# uplimit 0        30.741667
# 1        30.000000
# 2        30.606667
# 3        29.588333
# 4        28.666666
#            ...
# 46554    46.046665
# 46555    47.341667
# 46556    48.166668
# 46557    48.619602
# 46558    49.095001
# Name: GBX_OIL1_temp_C, Length: 46559, dtype: float64
# uplimit 0        30.741667
# 1        30.000000
# 2        30.606667
# 3        29.588333
# 4        28.666666
#            ...
# 46554    46.046665
# 46555    47.341667
# 46556    48.166668
# 46557    48.619602
# 46558    49.095001
# Name: GBX_OIL1_temp_C, Length: 46559, dtype: float64
# uplimit 0        33.000000
# 1        32.095001
# 2        33.000000
# 3        32.091667
# 4        30.430000
#            ...
# 46554    48.238335
# 46555    50.516666
# 46556    51.205002
# 46557    52.144520
# 46558    52.165001
# Name: GBX_OIL2_temp_C, Length: 46559, dtype: float64
# uplimit 0        33.000000
# 1        32.095001
# 2        33.000000
# 3        32.091667
# 4        30.430000
#            ...
# 46554    48.238335
# 46555    50.516666
# 46556    51.205002
# 46557    52.144520
# 46558    52.165001
# Name: GBX_OIL2_temp_C, Length: 46559, dtype: float64
# uplimit 0        33.000000
# 1        32.473331
# 2        33.000000
# 3        32.318333
# 4        31.695000
#            ...
# 46554    49.591667
# 46555    52.441666
# 46556    53.423332
# 46557    54.382061
# 46558    53.958332
# Name: GBX_T1_HSS_temp_C, Length: 46559, dtype: float64
# uplimit 0        33.000000
# 1        32.473331
# 2        33.000000
# 3        32.318333
# 4        31.695000
#            ...
# 46554    49.591667
# 46555    52.441666
# 46556    53.423332
# 46557    54.382061
# 46558    53.958332
# Name: GBX_T1_HSS_temp_C, Length: 46559, dtype: float64
# uplimit 0        36.000000
# 1        35.578335
# 2        35.848331
# 3        33.698334
# 4        32.415001
#            ...
# 46554    52.046665
# 46555    55.435001
# 46556    55.758335
# 46557    56.983387
# 46558    55.711666
# Name: GBX_T3_HSS_temp_C, Length: 46559, dtype: float64
# uplimit 0        36.000000
# 1        35.578335
# 2        35.848331
# 3        33.698334
# 4        32.415001
#            ...
# 46554    52.046665
# 46555    55.435001
# 46556    55.758335
# 46557    56.983387
# 46558    55.711666
# Name: GBX_T3_HSS_temp_C, Length: 46559, dtype: float64
# uplimit 0        29.388334
# 1        29.000000
# 2        29.388334
# 3        28.631666
# 4        28.000000
#            ...
# 46554    45.618332
# 46555    47.353333
# 46556    47.860001
# 46557    48.493355
# 46558    48.396667
# Name: GBX_T1_IMS_temp_C, Length: 46559, dtype: float64
# uplimit 0        29.388334
# 1        29.000000
# 2        29.388334
# 3        28.631666
# 4        28.000000
#            ...
# 46554    45.618332
# 46555    47.353333
# 46556    47.860001
# 46557    48.493355
# 46558    48.396667
# Name: GBX_T1_IMS_temp_C, Length: 46559, dtype: float64
# uplimit 0        32.271667
# 1        32.193333
# 2        32.384998
# 3        32.000000
# 4        32.000000
#            ...
# 46554    48.000000
# 46555    49.200001
# 46556    50.451668
# 46557    51.205978
# 46558    52.000000
# Name: GBX_T3_IMS_temp_C, Length: 46559, dtype: float64
# uplimit 0        32.271667
# 1        32.193333
# 2        32.384998
# 3        32.000000
# 4        32.000000
#            ...
# 46554    48.000000
# 46555    49.200001
# 46556    50.451668
# 46557    51.205978
# 46558    52.000000
# Name: GBX_T3_IMS_temp_C, Length: 46559, dtype: float64
# uplimit 0        30.536667
# 1        29.401667
# 2        31.000000
# 3        29.963333
# 4        25.626667
#            ...
# 46554    46.000000
# 46555    47.316666
# 46556    48.296665
# 46557    48.916943
# 46558    49.206665
# Name: GBX_Distr_temp_C, Length: 46559, dtype: float64
# uplimit 0        30.536667
# 1        29.401667
# 2        31.000000
# 3        29.963333
# 4        25.626667
#            ...
# 46554    46.000000
# 46555    47.316666
# 46556    48.296665
# 46557    48.916943
# 46558    49.206665
# Name: GBX_Distr_temp_C, Length: 46559, dtype: float64
# uplimit 0        30.741667
# 1        30.000000
# 2        30.606667
# 3        29.588333
# 4        28.666666
#            ...
# 46554    46.046665
# 46555    47.345001
# 46556    48.168335
# 46557    48.619602
# 46558    49.095001
# Name: GBX_OIL_temp_C, Length: 46559, dtype: float64
# uplimit 0        30.741667
# 1        30.000000
# 2        30.606667
# 3        29.588333
# 4        28.666666
# ...
# uplimit 0        16.000000
# 1        16.000000
# 2        16.000000
# 3        16.000000
# 4        16.000000
#            ...
# 46554    24.000000
# 46555    24.638334
# 46556    25.000000
# 46557    25.000000
# 46558    25.000000
# Name: Shaft_bearing2_temp_C, Length: 46559, dtype: float64
# i list2
# feature_fill {'feature_fill_list': ['Prox_sensor45_mm', 'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm', 'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree', 'Blade1_set_val_degree', 'Blade1_act_val_degree'], 'limit_conditions': ['None', -5]}
# feature_fill_list ['Prox_sensor45_mm', 'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm', 'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree', 'Blade1_set_val_degree', 'Blade1_act_val_degree']
# ['None', -5]
# upperlimit None
# lowerlimit -5
# uplimit 0        5.965685
# 1        5.962787
# 2        5.972196
# 3        5.966955
# 4        5.967192
#            ...
# 46554    5.872315
# 46555    5.800462
# 46556    5.835225
# 46557    5.802451
# 46558    5.880245
# Name: Prox_sensor45_mm, Length: 46559, dtype: float64
# uplimit 0        5.835482
# 1        5.844125
# 2        5.845551
# 3        5.852061
# 4        5.828049
#            ...
# 46554    5.729887
# 46555    5.704558
# 46556    5.750410
# 46557    5.715010
# 46558    5.725987
# Name: Prox_sensor135_mm, Length: 46559, dtype: float64
# uplimit 0        5.885922
# 1        5.890944
# 2        5.888516
# 3        5.864157
# 4        5.828836
#            ...
# 46554    5.762411
# 46555    5.751242
# 46556    5.759201
# 46557    5.760947
# 46558    5.774153
# Name: Prox_sensor225_mm, Length: 46559, dtype: float64
# uplimit 0        5.939926
# 1        5.932297
# 2        5.941095
# 3        5.921583
# 4        5.926690
#            ...
# 46554    5.822751
# 46555    5.764646
# 46556    5.765453
# 46557    5.767385
# 46558    5.845418
# Name: Prox_sensor315_mm, Length: 46559, dtype: float64
# uplimit 0         1.887551
# 1         2.523981
# 2        15.869534
# 3        65.000267
# 4        65.000267
#            ...
# 46554    -0.057536
# 46555    -0.057541
# 46556    -0.057540
# 46557    -0.057542
# 46558    -0.057537
# Name: Blade2_act_val_A_degree, Length: 46559, dtype: float64
# uplimit 0         2.425145
# 1         3.001387
# 2        16.247231
# 3        65.106438
# 4        65.106430
#            ...
# 46554     0.311668
# 46555     0.311659
# 46556     0.311666
# 46557     0.311662
# 46558     0.311668
# Name: Blade3_act_val_A_degree, Length: 46559, dtype: float64
# uplimit 0         1.805944
# 1         2.449929
# 2        15.835155
# 3        65.000000
# 4        65.000000
#            ...
# 46554    -0.141644
# 46555    -0.141644
# 46556    -0.141644
# 46557    -0.141644
# 46558    -0.141644
# Name: Blade1_set_val_degree, Length: 46559, dtype: float64
# uplimit 0         1.875937
# 1         2.514931
# 2        15.883361
# 3        65.067863
# 4        65.067871
#            ...
# 46554    -0.068534
# 46555    -0.068531
# 46556    -0.068531
# 46557    -0.068531
# 46558    -0.068531
# Name: Blade1_act_val_degree, Length: 46559, dtype: float64
# Tagname are : T27
# renamecolumns are : {'Unnamed: 0': 'Period', 'Bahce 27 Power (kW)': 'Power_kW', 'Bahce 27 Rotor speed (PLC) (rpm)': 'Rotor_rpm', 'Bahce 27 Nacelle position (°)': 'Nacelle_Position', 'Bahce 27 Generator speed (PLC) (rpm)': 'Generator_rpm', 'Bahce 27 Torque, actual value (%)': 'Torque_act_Percent', 'Bahce 27 Torque, set value (%)': 'Torque_set_Percent', 'Bahce 27 Tower acceleration  normal (mm/s²)': 'Tower_acc_normal', 'Bahce 27 Tower acceleration lateral (mm/s²)': 'Tower_acc_lateral', 'Bahce 27 Temp. tower base (°C)': 'Tower_base_temp_C', 'Bahce 27 Temp. Ambient (°C)': 'Ambient_temp_C', 'Bahce 27 Windspeed a. 1 (m/s)': 'Windspeed_m_s', 'Bahce 27 Temp. gear box bearing (°C)': 'gearboxbearing_temp_C', 'Bahce 27 Temp. GBX bearing hollow shaft (°C)': 'GBX_bearing_hollow_shaft_temp_C', 'Bahce 27 T_GBX_OIL_1 (°C)': 'GBX_OIL1_temp_C', 'Bahce 27 T_GBX_OIL_2 (°C)': 'GBX_OIL2_temp_C', 'Bahce 27 T_GBX_T1-HSS (°C)': 'GBX_T1_HSS_temp_C', 'Bahce 27 T_GBX_T3-HSS (°C)': 'GBX_T3_HSS_temp_C', 'Bahce 27 T_GBX_T1-IMS (°C)': 'GBX_T1_IMS_temp_C', 'Bahce 27 T_GBX_T3-IMS (°C)': 'GBX_T3_IMS_temp_C', 'Bahce 27 T_GBX_Distr (°C)': 'GBX_Distr_temp_C', 'Bahce 27 T_GBX_OIL (°C)': 'GBX_OIL_temp_C', 'Bahce 27 Temp. shaft bearing 1 (°C)': 'Shaft_bearing1_temp_C', 'Bahce 27 Temp. shaft bearing 2 (°C)': 'Shaft_bearing2_temp_C', 'Bahce 27 Prox. sensor 45° (mm)': 'Prox_sensor45_mm', 'Bahce 27 Prox. sensor 135° (mm)': 'Prox_sensor135_mm', 'Bahce 27 Prox. sensor 225° (mm)': 'Prox_sensor225_mm', 'Bahce 27 Prox. sensor 315° (mm)': 'Prox_sensor315_mm', 'Bahce 27 Blade 2, actual value A (°)': 'Blade2_act_val_A_degree', 'Bahce 27 Blade 3, actual value A (°)': 'Blade3_act_val_A_degree', 'Bahce 27 Blade 1, set value (°)': 'Blade1_set_val_degree', 'Bahce 27 Blade 1, actual value A (°)': 'Blade1_act_val_degree'}
# Before columns Index(['Unnamed: 0', 'Bahce 27 Power (kW)', 'Bahce 27 Rotor speed (PLC) (rpm)',
#        'Bahce 27 Nacelle position (°)', 'Bahce 27 Generator speed (PLC) (rpm)',
#        'Bahce 27 Torque, actual value (%)', 'Bahce 27 Torque, set value (%)',
#        'Bahce 27 Tower acceleration  normal (mm/s²)',
#        'Bahce 27 Tower acceleration lateral (mm/s²)',
#        'Bahce 27 Temp. tower base (°C)', 'Bahce 27 Temp. Ambient (°C)',
#        'Bahce 27 Windspeed a. 1 (m/s)', 'Bahce 27 Temp. gear box bearing (°C)',
#        'Bahce 27 Temp. GBX bearing hollow shaft (°C)',
#        'Bahce 27 T_GBX_OIL_1 (°C)', 'Bahce 27 T_GBX_OIL_2 (°C)',
#        'Bahce 27 T_GBX_T1-HSS (°C)', 'Bahce 27 T_GBX_T3-HSS (°C)',
#        'Bahce 27 T_GBX_T1-IMS (°C)', 'Bahce 27 T_GBX_T3-IMS (°C)',
#        'Bahce 27 T_GBX_Distr (°C)', 'Bahce 27 T_GBX_OIL (°C)',
#        'Bahce 27 Temp. shaft bearing 1 (°C)',
#        'Bahce 27 Temp. shaft bearing 2 (°C)', 'Bahce 27 Prox. sensor 45° (mm)',
#        'Bahce 27 Prox. sensor 135° (mm)', 'Bahce 27 Prox. sensor 225° (mm)',
#        'Bahce 27 Prox. sensor 315° (mm)',
#        'Bahce 27 Blade 2, actual value A (°)',
#        'Bahce 27 Blade 3, actual value A (°)',
#        'Bahce 27 Blade 1, set value (°)',
#        'Bahce 27 Blade 1, actual value A (°)'],
#       dtype='object')
# After columns Index(['Period', 'Power_kW', 'Rotor_rpm', 'Nacelle_Position', 'Generator_rpm',
#        'Torque_act_Percent', 'Torque_set_Percent', 'Tower_acc_normal',
#        'Tower_acc_lateral', 'Tower_base_temp_C', 'Ambient_temp_C',
#        'Windspeed_m_s', 'gearboxbearing_temp_C',
#        'GBX_bearing_hollow_shaft_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C',
#        'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C',
#        'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C',
#        'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C', 'Prox_sensor45_mm',
#        'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm',
#        'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree',
#        'Blade1_set_val_degree', 'Blade1_act_val_degree'],
#       dtype='object')
# i list1
# feature_fill {'feature_fill_list': ['Ambient_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C', 'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C', 'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C', 'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C'], 'limit_conditions': [100, -5]}
# feature_fill_list ['Ambient_temp_C', 'GBX_OIL1_temp_C', 'GBX_OIL2_temp_C', 'GBX_T1_HSS_temp_C', 'GBX_T3_HSS_temp_C', 'GBX_T1_IMS_temp_C', 'GBX_T3_IMS_temp_C', 'GBX_Distr_temp_C', 'GBX_OIL_temp_C', 'Shaft_bearing1_temp_C', 'Shaft_bearing2_temp_C']
# [100, -5]
# upperlimit 100
# lowerlimit -5
# uplimit 0       -2.000
# 1       -2.000
# 2       -2.000
# 3       -2.000
# 4       -2.000
#          ...
# 47303    8.000
# 47304    8.000
# 47305    8.000
# 47306    8.000
# 47307    7.935
# Name: Ambient_temp_C, Length: 47308, dtype: float64
# uplimit 0       -2.000
# 1       -2.000
# 2       -2.000
# 3       -2.000
# 4       -2.000
#          ...
# 47303    8.000
# 47304    8.000
# 47305    8.000
# 47306    8.000
# 47307    7.935
# Name: Ambient_temp_C, Length: 47308, dtype: float64
# uplimit 0        23.128334
# 1        23.430233
# 2        23.546511
# 3        24.793333
# 4        24.000000
#            ...
# 47303    61.169998
# 47304    62.884998
# 47305    63.224998
# 47306    60.728333
# 47307    63.000000
# Name: GBX_OIL1_temp_C, Length: 47308, dtype: float64
# uplimit 0        23.128334
# 1        23.430233
# 2        23.546511
# 3        24.793333
# 4        24.000000
#            ...
# 47303    61.169998
# 47304    62.884998
# 47305    63.224998
# 47306    60.728333
# 47307    63.000000
# Name: GBX_OIL1_temp_C, Length: 47308, dtype: float64
# uplimit 0        22.000000
# 1        22.988373
# 2        24.714285
# 3        28.293333
# 4        25.000000
#            ...
# 47303    61.095001
# 47304    62.746666
# 47305    62.986668
# 47306    60.573334
# 47307    63.000000
# Name: GBX_OIL2_temp_C, Length: 47308, dtype: float64
# uplimit 0        22.000000
# 1        22.988373
# 2        24.714285
# 3        28.293333
# 4        25.000000
#            ...
# 47303    61.095001
# 47304    62.746666
# 47305    62.986668
# 47306    60.573334
# 47307    63.000000
# Name: GBX_OIL2_temp_C, Length: 47308, dtype: float64
# uplimit 0        24.000000
# 1        24.000000
# 2        24.400331
# 3        25.848333
# 4        25.786667
#            ...
# 47303    60.421665
# 47304    62.855000
# 47305    64.339996
# 47306    62.823334
# 47307    64.000000
# Name: GBX_T1_HSS_temp_C, Length: 47308, dtype: float64
# uplimit 0        24.000000
# 1        24.000000
# 2        24.400331
# 3        25.848333
# 4        25.786667
#            ...
# 47303    60.421665
# 47304    62.855000
# 47305    64.339996
# 47306    62.823334
# 47307    64.000000
# Name: GBX_T1_HSS_temp_C, Length: 47308, dtype: float64
# uplimit 0        23.100000
# 1        23.000000
# 2        23.629568
# 3        24.860001
# 4        24.571667
#            ...
# 47303    60.000000
# 47304    61.378334
# 47305    62.608334
# 47306    62.148335
# 47307    62.271667
# Name: GBX_T3_HSS_temp_C, Length: 47308, dtype: float64
# uplimit 0        23.100000
# 1        23.000000
# 2        23.629568
# 3        24.860001
# 4        24.571667
#            ...
# 47303    60.000000
# 47304    61.378334
# 47305    62.608334
# 47306    62.148335
# 47307    62.271667
# Name: GBX_T3_HSS_temp_C, Length: 47308, dtype: float64
# uplimit 0        23.760000
# 1        24.340532
# 2        26.367109
# 3        28.434999
# 4        26.996666
#            ...
# 47303    62.223331
# 47304    65.129997
# 47305    66.383331
# 47306    63.886665
# 47307    66.573334
# Name: GBX_T1_IMS_temp_C, Length: 47308, dtype: float64
# uplimit 0        23.760000
# 1        24.340532
# 2        26.367109
# 3        28.434999
# 4        26.996666
#            ...
# 47303    62.223331
# 47304    65.129997
# 47305    66.383331
# 47306    63.886665
# 47307    66.573334
# Name: GBX_T1_IMS_temp_C, Length: 47308, dtype: float64
# uplimit 0        24.549999
# 1        24.000000
# 2        24.000000
# 3        24.000000
# 4        24.000000
#            ...
# 47303    61.000000
# 47304    61.770000
# 47305    63.338333
# 47306    61.633335
# 47307    62.115002
# Name: GBX_T3_IMS_temp_C, Length: 47308, dtype: float64
# uplimit 0        24.549999
# 1        24.000000
# 2        24.000000
# 3        24.000000
# 4        24.000000
#            ...
# 47303    61.000000
# 47304    61.770000
# 47305    63.338333
# 47306    61.633335
# 47307    62.115002
# Name: GBX_T3_IMS_temp_C, Length: 47308, dtype: float64
# uplimit 0        17.000000
# 1        16.551495
# 2        16.830564
# 3        18.000000
# 4        17.870001
#            ...
# 47303    55.759998
# 47304    56.645000
# 47305    53.790001
# 47306    50.869999
# 47307    56.836666
# Name: GBX_Distr_temp_C, Length: 47308, dtype: float64
# uplimit 0        17.000000
# 1        16.551495
# 2        16.830564
# 3        18.000000
# 4        17.870001
#            ...
# 47303    55.759998
# 47304    56.645000
# 47305    53.790001
# 47306    50.869999
# 47307    56.836666
# Name: GBX_Distr_temp_C, Length: 47308, dtype: float64
# uplimit 0        23.131666
# 1        23.430233
# 2        23.546511
# 3        24.793333
# 4        24.000000
#            ...
# 47303    61.169998
# 47304    62.884998
# 47305    63.223331
# 47306    60.728333
# 47307    63.000000
# Name: GBX_OIL_temp_C, Length: 47308, dtype: float64
# uplimit 0        23.131666
# 1        23.430233
# 2        23.546511
# 3        24.793333
# 4        24.000000
#            ...
# 47303    61.169998
# 47304    62.884998
# 47305    63.223331
# 47306    60.728333
# 47307    63.000000
# Name: GBX_OIL_temp_C, Length: 47308, dtype: float64
# uplimit 0        17.000000
# 1        17.000000
# 2        17.000000
# 3        17.000000
# 4        17.000000
#            ...
# 47303    34.000000
# 47304    34.174999
# 47305    35.000000
# 47306    35.000000
# 47307    35.000000
# Name: Shaft_bearing1_temp_C, Length: 47308, dtype: float64
# uplimit 0        17.000000
# 1        17.000000
# 2        17.000000
# 3        17.000000
# 4        17.000000
#            ...
# 47303    34.000000
# 47304    34.174999
# 47305    35.000000
# 47306    35.000000
# 47307    35.000000
# Name: Shaft_bearing1_temp_C, Length: 47308, dtype: float64
# uplimit 0        16.743334
# 1        16.196012
# 2        16.697674
# 3        17.000000
# 4        16.641666
#            ...
# 47303    29.000000
# 47304    29.000000
# 47305    29.000000
# 47306    29.000000
# 47307    29.000000
# Name: Shaft_bearing2_temp_C, Length: 47308, dtype: float64
# uplimit 0        16.743334
# 1        16.196012
# 2        16.697674
# 3        17.000000
# 4        16.641666
#            ...
# 47303    29.000000
# 47304    29.000000
# 47305    29.000000
# 47306    29.000000
# 47307    29.000000
# Name: Shaft_bearing2_temp_C, Length: 47308, dtype: float64
# i list2
# feature_fill {'feature_fill_list': ['Prox_sensor45_mm', 'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm', 'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree', 'Blade1_set_val_degree', 'Blade1_act_val_degree'], 'limit_conditions': ['None', -5]}
# feature_fill_list ['Prox_sensor45_mm', 'Prox_sensor135_mm', 'Prox_sensor225_mm', 'Prox_sensor315_mm', 'Blade2_act_val_A_degree', 'Blade3_act_val_A_degree', 'Blade1_set_val_degree', 'Blade1_act_val_degree']
# ['None', -5]
# upperlimit None
# lowerlimit -5
# uplimit 0        5.864533
# 1        5.866578
# 2        5.867957
# 3        5.861217
# 4        5.864900
#            ...
# 47303    5.823817
# 47304    5.759367
# 47305    5.757683
# 47306    5.751400
# 47307    5.773633
# Name: Prox_sensor45_mm, Length: 47308, dtype: float64
# uplimit 0        5.827083
# 1        5.821345
# 2        5.810000
# 3        5.821400
# 4        5.824533
#            ...
# 47303    5.848117
# 47304    5.848117
# 47305    5.822100
# 47306    5.840217
# 47307    5.858917
# Name: Prox_sensor135_mm, Length: 47308, dtype: float64
# uplimit 0        5.814550
# 1        5.809003
# 2        5.796661
# 3        5.809683
# 4        5.810567
#            ...
# 47303    5.869000
# 47304    5.889283
# 47305    5.871500
# 47306    5.877333
# 47307    5.879183
# Name: Prox_sensor225_mm, Length: 47308, dtype: float64
# uplimit 0        5.822150
# 1        5.821894
# 2        5.823721
# 3        5.817266
# 4        5.820300
#            ...
# 47303    5.801700
# 47304    5.758450
# 47305    5.763300
# 47306    5.748833
# 47307    5.754983
# Name: Prox_sensor315_mm, Length: 47308, dtype: float64
# uplimit 0        65.000000
# 1        46.184635
# 2         6.644236
# 3        57.160534
# 4        65.000000
#            ...
# 47303     0.423317
# 47304     0.420583
# 47305     0.420450
# 47306     0.420067
# 47307     0.420667
# Name: Blade2_act_val_A_degree, Length: 47308, dtype: float64
# uplimit 0        65.000000
# 1        46.128639
# 2         6.511927
# 3        57.141335
# 4        65.000000
#            ...
# 47303     0.180000
# 47304     0.180000
# 47305     0.180000
# 47306     0.180000
# 47307     0.180000
# Name: Blade3_act_val_A_degree, Length: 47308, dtype: float64
# uplimit 0        65.000000
# 1        45.827408
# 2         5.779418
# 3        57.055466
# 4        65.000000
#            ...
# 47303    -0.600000
# 47304    -0.600000
# 47305    -0.600000
# 47306    -0.600000
# 47307    -0.600000
# Name: Blade1_set_val_degree, Length: 47308, dtype: float64
# uplimit 0        65.000000
# 1        45.827244
# 2         5.802276
# 3        57.034832
# 4        65.000000
#            ...
# 47303    -0.600000
# 47304    -0.600000
# 47305    -0.600000
# 47306    -0.600000
# 47307    -0.600000
# Name: Blade1_act_val_degree, Length: 47308, dtype: float64

# %% [markdown]
# # Label Extraction

# %%
#####03_Create Labels#####
for TagName in config["Upload_list_all"]["Upload_Tags"]:
    
    tag=config["Upload_list_all"][TagName]
    print(TagName)
    component=config["Upload_list_all"]['External_Datasets']['Component']

    #Download Pickle Files
    Logs_Faults=download_pickle(intermediate_path,'Logs_Faults'+TagName)
    FaultComponent=download_pickle(raw_path,'FaultComponent')

    #Event referans alarak once binary sonra multiclass sonra da onehot labellar oluştur.
    #Yeni Labellar oluşturmadan önceki kolon sayısı before_size_df
    Features,Labels=create_labels(Logs_Faults,'Events',FaultComponent)

    # Save Features and Labels:
    save_dataset_pickle(intermediate_path,'Labels' + TagName,Labels)
    save_dataset_pickle(intermediate_path,'Features' + TagName,Features)
# Out:
# T02
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-f6acf2217da9> in <module>
#       9     Logs_Faults=download_pickle(intermediate_path,'Logs_Faults'+TagName)
#      10     FaultComponent=download_pickle(raw_path,'FaultComponent')
# ---> 11     FaultComponent=FaultComponent.drop('Unnamed: 0',axis='columns')
#      12     #Event referans alarak once binary sonra multiclass sonra da onehot labellar oluştur.
#      13     #Yeni Labellar oluşturmadan önceki kolon sayısı before_size_df
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"
